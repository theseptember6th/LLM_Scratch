# %%
# pip install youtube-transcript-api

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# from youtube_transcript_api import YouTubeTranscriptApi, TranscriptsDisabled

# video_id = "LPZh9BOjkQs"

# try:
#     api = YouTubeTranscriptApi()
#     transcript_obj = api.fetch(video_id=video_id, languages=["en"])

#     # Use .text attribute instead of ["text"]
#     transcript = " ".join(snippet.text for snippet in transcript_obj)

#     print(transcript)  # full concatenated text

# except TranscriptsDisabled:
#     print("No captions available for this video.")
# except Exception as e:
#     print(f"An unexpected error occurred: {e}")
# Out:
# Imagine you happen across a short movie script that describes a scene between a person and their AI assistant. The script has what the person asks the AI, but the AI's response has been torn off. Suppose you also have this powerful magical machine that can take any text and provide a sensible prediction of what word comes next. You could then finish the script by feeding in what you have to the machine, seeing what it would predict to start the AI's answer, and then repeating this over and over with a growing script completing the dialogue. When you interact with a chatbot, this is exactly what's happening. A large language model is a sophisticated mathematical function that predicts what word comes next for any piece of text. Instead of predicting one word with certainty, though, what it does is assign a probability to all possible next words. To build a chatbot, you lay out some text that describes an interaction between a user and a hypothetical AI assistant, add on whatever the u
# ...

# %%
# transcript_obj
# Out:
# FetchedTranscript(snippets=[FetchedTranscriptSnippet(text='Imagine you happen across a short movie script that', start=1.14, duration=2.836), FetchedTranscriptSnippet(text='describes a scene between a person and their AI assistant.', start=3.976, duration=3.164), FetchedTranscriptSnippet(text="The script has what the person asks the AI, but the AI's response has been torn off.", start=7.48, duration=5.58), FetchedTranscriptSnippet(text='Suppose you also have this powerful magical machine that can take', start=13.06, duration=3.92), FetchedTranscriptSnippet(text='any text and provide a sensible prediction of what word comes next.', start=16.98, duration=3.98), FetchedTranscriptSnippet(text='You could then finish the script by feeding in what you have to the machine,', start=21.5, duration=4.006), FetchedTranscriptSnippet(text="seeing what it would predict to start the AI's answer,", start=25.506, duration=2.862), FetchedTranscriptSnippet(text='and then repeating this over and over wit
# ...

# %% [markdown]
# # for fetching transcript from campus X video,u need to change language to "hi"

# %%
# from youtube_transcript_api import YouTubeTranscriptApi, TranscriptsDisabled

# video_id = "WuEGXlokpuQ"

# try:
#     api = YouTubeTranscriptApi()
#     transcript_obj = api.fetch(video_id=video_id, languages=["hi"])

#     # Use .text attribute instead of ["text"]
#     transcript = " ".join(snippet.text for snippet in transcript_obj)

#     print(transcript)  # full concatenated text

# except TranscriptsDisabled:
#     print("No captions available for this video.")
# except Exception as e:
#     print(f"An unexpected error occurred: {e}")
# Out:
# हाय गाइस माय नेम इज नितेश एंड यू वेलकम टू माय youtube2 प्रोजेक्ट्स बना रखे हैं और यह प्रोजेक्ट्स पे बहुत सारे व्यूज आते हैं और दिस इज समथिंग जो मेरे चैनल के टॉप वीडियोस में से एक है द ओनली प्रॉब्लम विद दिस प्लेलिस्ट इज कि इस प्लेलिस्ट में जो मैक्सिमम प्रोजेक्ट्स मैंने बनाए हैं उनको डिप्लॉयड की थी पास्ट में और उस सर्विस का नाम है रोकू अब रोकू एज अ सर्विस उस टाइम पर एक फ्री टियर का ऑप्शन देती थी व्हिच मींस कि आपके जैसे लोग और मेरे जैसे लोग जो प्रॉपर कंपनी सेटअप में प्रोजेक्ट्स नहीं बना रहे हैं बल्कि हॉबी लेवल पे या अपना पोर्टफोलियो बिल्ड करने के लिए प्रोजेक्ट बना रहे हैं वह बहुत आसानी से इस प्लेटफार्म को यूज करके अपने प्रोजेक्ट को डिप्लॉयडी इनके पैसे खत्म हो गए और इवेंचर कुू डिसाइडेड कि वह अपना फ्री टेयर वाला प्लान हटा देंगे व्हिच मेंट कि अगर आपको रोकू पे कुछ भी डिप्लॉयड से सिंपल प्रोजेक्ट भी तो आपको उसके पैसे देने पड़ेंगे अब आई नो आप लोगों में से बहुत लोग स्टूडेंट्स हो और सिर्फ डिप्लॉयड के लिए आप कहीं पर पैसे नहीं लगा सकते और यह एक बहुत बड़ी प्रॉब्लम बन गई और उसके बाद से क्या हुआ कि ल
# ...

# %% [markdown]
# # we will be using this one

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from youtube_transcript_api import YouTubeTranscriptApi, TranscriptsDisabled

video_id = "P0enFK4bzLE" #Gfr50f6ZBvo

try:
    api = YouTubeTranscriptApi()
    transcript_obj = api.fetch(video_id=video_id, languages=["en"])

    # Use .text attribute instead of ["text"]
    transcript = " ".join(snippet.text for snippet in transcript_obj)

    print(transcript)  # full concatenated text

except TranscriptsDisabled:
    print("No captions available for this video.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# But really what separates great scientists from good scientists is their creativity and their sort of maybe you could call it a taste for what's the right question um what's the right hypothesis and it's much harder to come up with the right question and the right hypothesis than it is to solve a conjecture and um you know I would call that the highest level of sort of creativity and so far today's systems you know they don't have that capability um you know one way we maybe would test that is you could imagine training a foundation model with a knowledge cutoff of something like 1911 uh and then see if it could come up with general relativity like Einstein did in 1915. Um but that would be a good test I think for AGI and I think today's systems clearly would not be capable of doing that but I think this will be solved in time. >> Okay that's that's great. So you talked about uh scientific tool a tool for scientific discovery right and so we see a lot of you know headlines about AI y
# ...

# %%
len(transcript)
# Out:
# 27578

# %%
transcript_obj
# Out:
# FetchedTranscript(snippets=[FetchedTranscriptSnippet(text='But really what separates great', start=0.16, duration=3.84), FetchedTranscriptSnippet(text='scientists from good scientists is their', start=1.839, duration=4.48), FetchedTranscriptSnippet(text='creativity and their sort of maybe you', start=4.0, duration=4.4), FetchedTranscriptSnippet(text="could call it a taste for what's the", start=6.319, duration=3.841), FetchedTranscriptSnippet(text="right question um what's the right", start=8.4, duration=4.0), FetchedTranscriptSnippet(text="hypothesis and it's much harder to come", start=10.16, duration=4.72), FetchedTranscriptSnippet(text='up with the right question and the right', start=12.4, duration=4.879), FetchedTranscriptSnippet(text='hypothesis than it is to solve a', start=14.88, duration=5.36), FetchedTranscriptSnippet(text='conjecture and um you know I would call', start=17.279, duration=4.401), FetchedTranscriptSnippet(text='that the highest level of sort of', start=20.24
# ...

# %%
type(transcript_obj)
# Out:
# youtube_transcript_api._transcripts.FetchedTranscript
