# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### Import

# %%
from langchain_community.document_loaders import CSVLoader

# %% [markdown]
# ##### Loader for a CSV file

# %%
loader=CSVLoader(
    file_path="./5_Social_Network_Ads.csv"
)

# %% [markdown]
# ##### load all the rows

# %%
docs=loader.load()
print(f"Total rows/documents loaded: {len(docs)}")
# Out:
# Total rows/documents loaded: 400

# %%
docs
# Out:
# [Document(metadata={'source': './5_Social_Network_Ads.csv', 'row': 0}, page_content='User ID: 15624510\nGender: Male\nAge: 19\nEstimatedSalary: 19000\nPurchased: 0'),
#  Document(metadata={'source': './5_Social_Network_Ads.csv', 'row': 1}, page_content='User ID: 15810944\nGender: Male\nAge: 35\nEstimatedSalary: 20000\nPurchased: 0'),
#  Document(metadata={'source': './5_Social_Network_Ads.csv', 'row': 2}, page_content='User ID: 15668575\nGender: Female\nAge: 26\nEstimatedSalary: 43000\nPurchased: 0'),
#  Document(metadata={'source': './5_Social_Network_Ads.csv', 'row': 3}, page_content='User ID: 15603246\nGender: Female\nAge: 27\nEstimatedSalary: 57000\nPurchased: 0'),
#  Document(metadata={'source': './5_Social_Network_Ads.csv', 'row': 4}, page_content='User ID: 15804002\nGender: Male\nAge: 19\nEstimatedSalary: 76000\nPurchased: 0'),
# ...

# %%
type(docs)
# Out:
# list

# %% [markdown]
# ##### acess the first row

# %%
first_row=docs[0]
type(first_row)
# Out:
# langchain_core.documents.base.Document

# %%
print(f"MetaData:\n {first_row.metadata}")
print(f"\nContent of the first row :\n{first_row.page_content}")
# Out:
# MetaData:
#  {'source': './5_Social_Network_Ads.csv', 'row': 0}
#
# Content of the first row :
# User ID: 15624510
# Gender: Male
# Age: 19
# EstimatedSalary: 19000
# Purchased: 0

# %%
type(docs[0].page_content)
# Out:
# str
