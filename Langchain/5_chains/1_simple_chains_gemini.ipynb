# %% [markdown]
# ### 1.Define Model and Parser

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv
import os


load_dotenv()
api_key = os.getenv("GOOGLE_API_KEY")

model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite", google_api_key=api_key)

# %%
from langchain_core.output_parsers import StrOutputParser
parser=StrOutputParser()

# %% [markdown]
# ### 2.define the prompt template

# %%
from langchain_core.prompts import PromptTemplate
template=PromptTemplate(
    template="Generate 5 interesting facts about {topic}",
    input_variables=["topic"]
)

# %% [markdown]
# ### 3.create the chain and invoke

# %%
chain = template | model | parser
result=chain.invoke({
   "topic":"Cricket" 
})

# %% [markdown]
# ### 4.Output

# %%
print(result)
# Out:
# Here are 5 interesting facts about cricket:
#
# 1.  **The longest Test match in history lasted for 12 days!** Played between England and South Africa in 1939, the match was eventually declared a draw because the ship carrying the English team back home was scheduled to depart. The game itself was only played on 9 of those days due to weather interruptions.
#
# 2.  **The "Bodyline" bowling controversy led to a significant rule change.** In the 1932-33 Ashes series, the English team, led by Douglas Jardine, employed a tactic known as "bodyline" bowling. This involved bowling fast, short-pitched deliveries aimed at the batsman's body, with a packed leg-side field. It was highly effective but considered unsporting and dangerous. The tactic was so controversial that it led to the introduction of a rule limiting the number of short-pitched balls a bowler could deliver per over.
#
# 3.  **The fastest recorded cricket ball was bowled at a staggering 161.3 km/h (100.2 mph).** This incredible feat was achieved by Pakistan's Shoaib Akhtar during a match against England in 2003. He's one of the few bowlers to have officially broken the 100 mph barrier.
#
# 4.  **The iconic "sticky wicket" was a real phenomenon and a major challenge.** In the days before modern pitch preparation and covers, pitches were often made of natural soil and grass. If it rained, the pitch would become soft and uneven, making batting incredibly difficult and dangerous. Batsmen would often get stuck in the mud, hence the term "sticky wicket." This led to the development of covered pitches to protect them from the elements.
#
# 5.  **The term "cricket" might have originated from a medieval game or a French word.** While its exact origin is debated, one theory suggests it evolved from a children's game called "creag" or "cric" played in southern England. Another theory points to the Old French word "criquet," meaning a wooden frame or stand, which could refer to the wickets. Regardless of its precise roots, the name has become synonymous with one of the world's most popular sports.

# %%
print(type(result))
# Out:
# <class 'langchain_core.messages.base.TextAccessor'>

# %% [markdown]
# ### 5.Visualize the chain

# %%
chain.get_graph().print_ascii()
# Out:
#       +-------------+
#       | PromptInput |
#       +-------------+
#              *
#              *
#              *
#     +----------------+
#     | PromptTemplate |
#     +----------------+
#              *
#              *
#              *
# +------------------------+
# | ChatGoogleGenerativeAI |
# +------------------------+
#              *
#              *
#              *
#     +-----------------+
#     | StrOutputParser |
#     +-----------------+
#              *
#              *
#              *
# +-----------------------+
# | StrOutputParserOutput |
# +-----------------------+
