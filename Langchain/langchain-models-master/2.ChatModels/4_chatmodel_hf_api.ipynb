# %%
from langchain_huggingface import ChatHuggingFace, HuggingFaceEndpoint
from dotenv import load_dotenv
import os

# Load environment variables
load_dotenv()

api_key = os.getenv("Hugging_face_api_token")

# Create LLM endpoint
llm = HuggingFaceEndpoint(
    # repo_id="TinyLlama/TinyLlama-1.1B-Chat-v1.0",
    repo_id="mistralai/Mistral-7B-Instruct-v0.2",
    task="text-generation",
    huggingfacehub_api_token=api_key,
)

# Wrap with chat interface
model = ChatHuggingFace(llm=llm)

# Ask question
result = model.invoke("What is the capital of Nepal?")

print(result)
# Out:
# content=' The capital city of Nepal is Kathmandu. It is the largest city in the country and is located in the central part of Nepal. Kathmandu is known for its rich cultural heritage, with numerous historical and religious sites, including several UNESCO World Heritage Sites. The city has a population of over 1.5 million people and serves as the political, cultural, and economic center of Nepal.' additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 86, 'prompt_tokens': 16, 'total_tokens': 102}, 'model_name': 'mistralai/Mistral-7B-Instruct-v0.2', 'system_fingerprint': '', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019d0fa4-58bc-71b2-9b4a-0b9e85646c7b-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 16, 'output_tokens': 86, 'total_tokens': 102}

# %%
result.content
# Out:
# ' The capital city of Nepal is Kathmandu. It is the largest city in the country and is located in the central part of Nepal. Kathmandu is known for its rich cultural heritage, with numerous historical and religious sites, including several UNESCO World Heritage Sites. The city has a population of over 1.5 million people and serves as the political, cultural, and economic center of Nepal.'

# %%
type(result)
# Out:
# langchain_core.messages.ai.AIMessage
