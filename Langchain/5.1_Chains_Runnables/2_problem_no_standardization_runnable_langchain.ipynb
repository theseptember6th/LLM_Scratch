# %% [markdown]
# # sequential way

# %%
import random
class NakliLLM:
  def __init__(self):
    print("LLM created")

  def predict(self,prompt):
    response_list=[
        "Kathmandu is the capital of Nepal",
        "IPL is a cricket league",
        "AI stands for Artificial Intelligence"
    ]
    return {"response":random.choice(response_list)}

# %%
# llm=NakliLLM()
# llm.predict("What is the capital of Nepal?")

# %%
class NalkiPromptTemplate:
  def __init__(self,template,input_variables):
    self.template=template
    self.input_variables=input_variables

  def format(self,input_dict):
    return self.template.format(**input_dict)

# %%
template=NalkiPromptTemplate(
    template="Write a {length} poem about {topic}",
    input_variables=["length","topic"]
)

# %%
# template.format({"length":"short","topic":"Nepal"})

# %%
prompt=template.format({"length":"short","topic":"Nepal"})

# %%
llm=NakliLLM()
# Out:
# LLM created

# %%
llm.predict(prompt)
# Out:
# {'response': 'Kathmandu is the capital of Nepal'}

# %%
# connecting them through chains to both of them

# %%
class NalkiLLMChain:
  def __init__(self,llm,prompt):
    self.llm=llm
    self.prompt=prompt

  def run(self,input_dict):
    final_prompt=self.prompt.format(input_dict)
    result=self.llm.predict(final_prompt)

    return result["response"]

# %%
template=NalkiPromptTemplate(
    template="Write a {length} poem about {topic}",
    input_variables=["length","topic"]
)

# %%
chain=NalkiLLMChain(llm,template)

# %%
chain.run({"length":"short","topic":"india"})
# Out:
# 'IPL is a cricket league'

# %% [markdown]
# ## Problem:Cant have series of multiple chains,because there is no standardization
