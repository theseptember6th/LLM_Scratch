# %% [markdown]
# # using hugging face api

# %%
from langchain_huggingface import ChatHuggingFace, HuggingFaceEndpoint
from dotenv import load_dotenv
import os

# Load environment variables
load_dotenv()

api_key = os.getenv("Hugging_face_api_token")

# Create LLM endpoint
llm = HuggingFaceEndpoint(
    # repo_id="TinyLlama/TinyLlama-1.1B-Chat-v1.0",
    repo_id="mistralai/Mistral-7B-Instruct-v0.2",
    task="text-generation",
    huggingfacehub_api_token=api_key,
    max_new_tokens=20, # just for testing
    temperature=0.5
)

# Wrap with chat interface
model = ChatHuggingFace(llm=llm)

# %%
from langchain_core.messages import SystemMessage,AIMessage,HumanMessage
messages=[
    SystemMessage(content="You are a helpful assistant"),
    HumanMessage(content="Tell me about the langchain")
]
print(messages)
# Out:
# [SystemMessage(content='You are a helpful assistant', additional_kwargs={}, response_metadata={}), HumanMessage(content='Tell me about the langchain', additional_kwargs={}, response_metadata={})]

# %%
result=model.invoke(messages)
messages.append(AIMessage(content=result.content))
print(messages)
# Out:
# [SystemMessage(content='You are a helpful assistant', additional_kwargs={}, response_metadata={}), HumanMessage(content='Tell me about the langchain', additional_kwargs={}, response_metadata={}), AIMessage(content=' Langchain is a decentralized language learning platform built on the blockchain. It aims to provide', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[])]

# %% [markdown]
# ## this labelling allows the model to correctly interpret the flow of the conversation

# %% [markdown]
# # using gemini

# %%
from langchain_core.messages import SystemMessage, HumanMessage, AIMessage
import os


from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv

load_dotenv()
model = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash-lite", google_api_key=os.getenv("GOOGLE_API_KEY")
)
messages = [
    SystemMessage(content="You are a helpful asssistant."),
    HumanMessage(content="tell me about the langchain"),
]

result = model.invoke(messages)
messages.append(AIMessage(content=result.content))

print(messages)
# Out:
# [SystemMessage(content='You are a helpful asssistant.', additional_kwargs={}, response_metadata={}), HumanMessage(content='tell me about the langchain', additional_kwargs={}, response_metadata={}), AIMessage(content="LangChain is a powerful and rapidly evolving open-source framework designed to **simplify the development of applications that leverage large language models (LLMs)**. Think of it as a toolkit that helps you connect LLMs with other data sources and computational resources, enabling you to build more sophisticated and useful AI-powered applications.\n\nHere's a breakdown of what LangChain is, its key concepts, and why it's so popular:\n\n**The Core Problem LangChain Solves:**\n\nLLMs are incredibly powerful for generating text, answering questions, and performing various language-related tasks. However, building a full-fledged application around them often requires more than just calling an LLM API. You might need to:\n\n*   **Access external data:** LLMs have a knowledge cutoff and can't access real-time information or your private documents.\n*   **Perform complex reasoning:** LLMs can sometimes hallucinate or provide incomplete answers. You might need to break down complex tasks into smaller steps and use LLMs for specific parts.\n*   **Interact with tools:** LLMs can't directly execute code, browse the web, or interact with databases.\n*   **Manage conversations:** Maintaining context and memory in a dialogue is crucial for many applications.\n\nLangChain provides a structured way to address these challenges.\n\n**Key Concepts and Components of LangChain:**\n\nLangChain is built around several modular components that can be combined to create complex applications. Here are the most important ones:\n\n1.  **LLMs (Language Models):**\n    *   LangChain provides a standardized interface to interact with various LLM providers (OpenAI, Hugging Face, Anthropic, Cohere, etc.). This allows you to easily switch between different models without rewriting your code.\n\n2.  **Prompts:**\n    *   **Prompt Templates:** These are pre-defined structures for creating prompts that can be dynamically filled with user input. This helps in generating consistent and effective prompts.\n    *   **Output Parsers:** These tools help in structuring the output from LLMs into a desired format (e.g., JSON, lists, specific data types).\n\n3.  **Chains:**\n    *   This is a core concept in LangChain. Chains allow you to **sequence multiple LLM calls or other components together**. For example, you could have a chain that first retrieves information from a document, then uses an LLM to summarize it, and finally uses another LLM to answer a question based on the summary.\n    *   **Sequential Chains:** Simple linear execution of components.\n    *   **Router Chains:** Chains that intelligently choose which sub-chain to execute based on the input.\n\n4.  **Indexes (Data Connection):**\n    *   This is how LangChain helps LLMs access external data.\n    *   **Document Loaders:** Tools to load data from various sources like files (PDFs, text, CSVs), websites, databases, Notion, etc.\n    *   **Text Splitters:** For breaking down large documents into smaller chunks that can be processed by LLMs.\n    *   **Vector Stores:** A crucial component for semantic search. LangChain integrates with various vector databases (Chroma, Pinecone, Weaviate, FAISS, etc.) to store embeddings of your documents.\n    *   **Retrievers:** These are interfaces for querying your data. A retriever takes a user's query, converts it into an embedding, and then searches the vector store for the most relevant document chunks.\n\n5.  **Memory:**\n    *   Enables LLM applications to **retain information from previous interactions**, making conversations feel more natural and context-aware.\n    *   **ConversationBufferMemory:** Stores the raw conversation history.\n    *   **ConversationSummaryMemory:** Summarizes the conversation to save context window space.\n\n6.  **Agents:* ...
