# %%
import os
from langchain_huggingface import HuggingFacePipeline, ChatHuggingFace
"""
os.environ["HF_HOME"] = "/Users/kristalshrestha/Documents/Code/LLM_Scratch/models"
llm = HuggingFacePipeline.from_model_id(
    model_id="TinyLlama/TinyLlama-1.1B-Chat-v1.0",
    task="text-generation",
    pipeline_kwargs={
        "max_new_tokens": 100,
        "temperature": 0.5,
    },
)
"""
from langchain_huggingface import ChatHuggingFace, HuggingFaceEndpoint
from dotenv import load_dotenv
import os

# Load environment variables
load_dotenv()

api_key = os.getenv("Hugging_face_api_token")

# Create LLM endpoint
llm = HuggingFaceEndpoint(
    # repo_id="TinyLlama/TinyLlama-1.1B-Chat-v1.0",
    repo_id="mistralai/Mistral-7B-Instruct-v0.2",
    task="text-generation",
    huggingfacehub_api_token=api_key,
    max_new_tokens=200,
    temperature=0.5
)

# Wrap with chat interface
model = ChatHuggingFace(llm=llm)

# %%
chat_history = []
while True:
    user_input = input("You: ")
    chat_history.append(user_input)
    if user_input.strip().lower() == "exit":
        break
    result = model.invoke(chat_history)
    chat_history.append(result.content)
    print(f"AI: {result.content}")


print(chat_history)
# Out:
# AI:  Hello! How can I help you today? If you have any questions or topics you'd like to discuss, feel free to ask. I'm here to provide information and answer any questions you might have. Let me know if you need assistance with something specific.
# AI:  Narendra Modi is a prominent Indian politician who has served as the Prime Minister of India since May 2014. He was born on September 17, 1950, in Vadnagar, Gujarat, India. Before becoming Prime Minister, Modi served as the Chief Minister of Gujarat from 2001 to 2014. He is the leader of the Bharatiya Janata Party (BJP) and is known for his nationalist and pro-business policies. Modi's tenure as Prime Minister has been marked by several major initiatives, including the implementation of the Goods and Services Tax (GST), the demonetization of high-value currency notes, and the launch of the Swachh Bharat Abhiyan (Clean India Mission). Modi is also known for his strong leadership style and his focus on promoting India as a global economic power.
# AI:  Narendra Modi was born on September 17, 1950. So, as of 2023, he is 72 years old.
# ['Hi', " Hello! How can I help you today? If you have any questions or topics you'd like to discuss, feel free to ask. I'm here to provide information and answer any questions you might have. Let me know if you need assistance with something specific.", 'who is modi?', " Narendra Modi is a prominent Indian politician who has served as the Prime Minister of India since May 2014. He was born on September 17, 1950, in Vadnagar, Gujarat, India. Before becoming Prime Minister, Modi served as the Chief Minister of Gujarat from 2001 to 2014. He is the leader of the Bharatiya Janata Party (BJP) and is known for his nationalist and pro-business policies. Modi's tenure as Prime Minister has been marked by several major initiatives, including the implementation of the Goods and Services Tax (GST), the demonetization of high-value currency notes, and the launch of the Swachh Bharat Abhiyan (Clean India Mission). Modi is also known for his strong leadership style and his focus on promoting India as a global economic power.", 'how old he is', ' Narendra Modi was born on September 17, 1950. So, as of 2023, he is 72 years old.', 'exit']
