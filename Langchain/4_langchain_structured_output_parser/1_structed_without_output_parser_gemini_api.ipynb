# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv
import os
from langchain_core.prompts import PromptTemplate

load_dotenv()
api_key = os.getenv("GOOGLE_API_KEY")


model = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash-lite",
    google_api_key=api_key,
)

# %%
# 1st prompt ->Detailed report
template1 = PromptTemplate(
    template="Write a detailed report on {topic}", input_variables=["topic"]
)
prompt1 = template1.invoke({"topic": "blackhole"})
print(f"Prompt1 : {prompt1}")
result = model.invoke(prompt1)
print(f"result: {result.content}")
# Out:
# Prompt1 : text='Write a detailed report on blackhole'
# result: ## Black Hole: A Cosmic Enigma
#
# **Report Date:** October 26, 2023
#
# **Prepared By:** [Your Name/AI Assistant]
#
# **Subject:** A Comprehensive Overview of Black Holes
#
# ---
#
# **1. Introduction**
#
# Black holes are among the most fascinating and enigmatic objects in the universe. These regions of spacetime possess such intense gravitational pull that nothing, not even light, can escape their grasp. Their existence, once a purely theoretical prediction of Einstein's theory of general relativity, has been confirmed through decades of observational evidence. This report aims to provide a detailed exploration of black holes, covering their formation, properties, types, detection methods, and their profound implications for our understanding of gravity and the cosmos.
#
# ---
#
# **2. Theoretical Foundation: General Relativity**
#
# The concept of black holes is deeply rooted in Albert Einstein's **theory of general relativity**, published in 1915. General relativity describes gravity not as a force, but as a curvature of spacetime caused by the presence of mass and energy.
#
# *   **Spacetime Curvature:** Massive objects warp the fabric of spacetime around them. This curvature dictates how other objects, including light, move.
# *   **Escape Velocity:** Every celestial object has an "escape velocity" – the minimum speed required to break free from its gravitational pull. For Earth, it's about 11.2 km/s.
# *   **Schwarzschild Radius:** In 1916, Karl Schwarzschild derived a solution to Einstein's field equations that described the spacetime around a non-rotating, spherically symmetric mass. This solution revealed that if enough mass is compressed into a small enough volume, the escape velocity at its surface would exceed the speed of light. The radius at which this occurs is known as the **Schwarzschild radius ($R_s$)**.
#
#     $R_s = \frac{2GM}{c^2}$
#
#     Where:
#     *   $G$ is the gravitational constant
#     *   $M$ is the mass of the object
#     *   $c$ is the speed of light
#
#     For a black hole, the Schwarzschild radius defines the boundary beyond which escape is impossible.
#
# ---
#
# **3. Formation of Black Holes**
#
# Black holes are believed to form through the gravitational collapse of massive objects. The primary mechanisms for their formation are:
#
# *   **Stellar-Mass Black Holes:** These are the most common type and are formed from the remnants of massive stars.
#     *   **Stellar Evolution:** Stars spend most of their lives fusing lighter elements into heavier ones in their core, generating outward pressure that counteracts the inward pull of gravity.
#     *   **Supernova Explosion:** When a massive star (typically more than 8-10 times the mass of our Sun) exhausts its nuclear fuel, the outward pressure ceases. Gravity then overwhelms the star's core, causing it to collapse catastrophically.
#     *   **Core Collapse:** If the core's mass after the collapse exceeds a certain limit (the Tolman-Oppenheimer-Volkoff limit, around 1.4-3 solar masses, depending on the equation of state of neutron-degenerate matter), it will continue to collapse indefinitely, forming a stellar-mass black hole. The outer layers of the star are expelled in a spectacular **supernova explosion**.
#
# *   **Supermassive Black Holes:** These behemoths, with masses ranging from millions to billions of solar masses, reside at the centers of most galaxies, including our own Milky Way (Sagittarius A*). Their formation is less well understood but likely involves:
#     *   **Mergers of Smaller Black Holes:** Stellar-mass black holes or intermediate-mass black holes may merge over cosmic time.
#     *   **Accretion of Gas and Dust:** Large amounts of gas and dust in the early universe may have rapidly fallen into central regions, leading to the formation of seed black holes that grew by accreting more matter.
#     *   **Direct Collapse of Gas Clouds:** In the early universe, massive gas clouds might have collapsed directly to form very massive black hole seeds.
#
# *   **Intermediate-Mass Black Holes (IMBHs):** These have masses between stellar-mass and supermassive black holes (hundreds to thousands of solar masses). Their existence is still debated, and their formation mechanisms are unclear. Potential origins include:
#     *   **Runaway Stellar Collisions:** In dense star clusters, stars might collide and merge to form a very massive star that then collapses into an IMBH.
#     *   **Mergers of Stellar-Mass Black Holes.**
#
# ---
#
# **4. Key Properties of Black Holes**
#
# Despite their complexity, black holes can be characterized by a surprisingly small number of properties, often referred to as the "no-hair theorem":
#
# *   **Mass (M):** The total amount of matter that has collapsed to form the black hole. This is the most crucial property determining its gravitational influence.
# *   **Spin (Angular Momentum, J):** Most black holes are expected to be rotating, a remnant of the rotation of the star or gas cloud from which they formed. Spin affects the spacetime around the black hole.
# *   **Electric Charge (Q):** While theoretically possible, astrophysical black holes are generally expected to have negligible electric charge, as they would quickly neutralize themselves by attracting opposite charges from their surroundings.
#
# **Anatomy of a Black Hole:**
#
# *   **Singularity:** At the heart of a black hole lies the **singularity**, a point of infinite density and zero volume where all the mass is concentrated. Our current understanding of physics breaks down at the singularity, and it remains a major area of theoretical research.
# *   **Event Horizon:** This is the boundary of no return. It's a spherical surface (for a non-rotating black hole) where the escape velocity equals the speed of light. Once an object crosses the event horizon, it is inevitably pulled towards the singularity. The size of the event horizon is determined by the Schwarzschild radius.
# *   **Ergosphere (for rotating black holes):** Rotating black holes (Kerr black holes) warp spacetime so intensely that they drag spacetime itself around with them in a phenomenon called **frame-dragging**. The ergosphere is a region outside the event horizon where spacetime is dragged around faster than the local speed of light. Objects within the ergosphere are forced to rotate with the black hole, and energy can be extracted from a rotating black hole via processes like the Penrose process.
#
# ---
#
# **5. Types of Black Holes**
#
# Black holes are broadly categorized by their mass:
#
# *   **Stellar-Mass Black Holes:** Typically 5 to tens of solar masses. Formed from the collapse of individual massive stars.
# *   **Supermassive Black Holes:** Millions to billions of solar masses. Found at galactic centers.
# *   **Intermediate-Mass Black Holes (IMBHs):** Hundreds to thousands of solar masses. Their existence and formation are still actively researched.
# *   **Primordial Black Holes (Hypothetical):** These are theoretical black holes that may have formed in the very early universe from density fluctuations. They could have a wide range of masses, from microscopic to stellar.
#
# ---
#
# **6. Detection of Black Holes**
#
# Since black holes do not emit light, their detection relies on observing their gravitational influence on their surroundings. Key detection methods include:
#
# *   **Gravitational Influence on Visible Matter:**
#     *   **Orbital Motion of Stars:** Observing stars orbiting an unseen, massive object provides strong evidence for a black hole. The speed and trajectory of these stars can be used to estimate the mass of the unseen object. This is how Sagittarius A* at the center of the Milky Way was confirmed.
#     *   **Binary Systems:** If a black hole is in a binary system with a visible star, the black hole's gravity can pull material from the star. This material forms an **accretion disk** around the black hole.
#
# *   **Accretion Disks and X-ray Emission:**
#     *   **Accretion Disk:** As gas and dust spiral into a black hole, they form a superheated accretion disk. Friction within the disk heats the material to millions of degrees, causing it to emit intense radiation, particularly in the X-ray spectrum.
#     *   **X-ray Telescopes:** Observing these X-ray emissions with specialized telescopes (like Chandra X-ray Observatory) is a primary method for identifying black holes.
#
# *   **Jets:**
#     *   **Relativistic Jets:** In some cases, particularly with supermassive black holes in active galactic nuclei (AGN), powerful jets of plasma are ejected at nearly the speed of light from the vicinity of the black hole, perpendicular to the accretion disk. These jets can be observed across the electromagnetic spectrum.
#
# *   **Gravitational Waves:**
#     *   **Mergers:** The merger of two black holes (or a black hole and a neutron star) generates ripples in spacetime called **gravitational waves**. These waves, predicted by Einstein, were first directly detected in 2015 by the LIGO (Laser Interferometer Gravitational-Wave Observatory) and Virgo collaborations. Gravitational wave astronomy has opened a new window for studying black holes and their interactions.
#
# *   **Event Horizon Telescope (EHT):**
#     *   **Direct Imaging:** The EHT, a global network of radio telescopes, has achieved the unprecedented feat of capturing the "shadow" of a black hole. The EHT observed the supermassive black hole at the center of the galaxy Messier 87 (M87*) and later Sagittarius A*. The shadow is the region around the black hole where light is so bent that it appears dark against the bright emission from the surrounding accretion disk.
#
# ---
#
# **7. Black Holes and Their Implications**
#
# Black holes are not just cosmic oddities; they play crucial roles in the universe and challenge our fundamental understanding of physics:
#
# *   **Galaxy Evolution:** Supermassive black holes at galactic centers are thought to be intimately linked to the growth and evolution of their host galaxies. Their feedback mechanisms, through jets and radiation, can regulate star formation.
# *   **Testing General Relativity:** Black holes provide extreme environments to test the validity of Einstein's theory of general relativity. Observations of gravitational waves and the shadow of black holes have so far strongly supported the predictions of relativity.
# *   **Quantum Gravity:** The singularity at the heart of a black hole represents a breakdown of current physics. Understanding what happens at the singularity requires a theory of **quantum gravity**, which would unify general relativity (describing gravity) with quantum mechanics (describing the very small).
# *   **Information Paradox:** A significant theoretical puzzle is the **black hole information paradox**. According to quantum mechanics, information cannot be destroyed. However, if a black hole evaporates through Hawking radiation (see below), it seems to lose the information about what fell into it. This paradox highlights the tension between general relativity and quantum mechanics.
# *   **Hawking Radiation (Theoretical):** Stephen Hawking proposed that black holes are not entirely black but slowly "evaporate" by emitting **Hawking radiation**, a thermal spectrum of particles. This radiation arises from quantum effects near the event horizon. While theoretically predicted, Hawking radiation is extremely weak for astrophysical black holes and has not been directly observed.
#
# ---
#
# **8. Conclusion**
#
# Black holes represent the extreme limits of gravity, pushing our current understanding of physics to its breaking point. From their formation through stellar collapse and galactic evolution to their detection via their gravitational influence and the groundbreaking observations of gravitational waves and the event horizon, black holes continue to captivate scientists and the public alike. Ongoing research into these cosmic enigmas promises to unlock deeper secrets about the nature of spacetime, gravity, and the fundamental laws governing our universe. The quest to understand black holes is a journey into the very fabric of reality.
#
# ---
#
# **9. References (Illustrative)**
#
# *   Einstein, A. (1916). Die Grundlage der allgemeinen Relativitätstheorie. *Annalen der Physik*, *354*(7), 769-822.
# *   Schwarzschild, K. (1916). Über das Gravitationsfeld eines Massenpunktes nach der Einsteinschen Theorie. *Sitzungsberichte der Königlich Preußischen Akademie der Wissenschaften zu Berlin*, *1916*, 189-196.
# *   Hawking, S. W. (1975). Particle creation by black holes. *Communications in Mathematical Physics*, *43*(3), 199-220.
# *   Abbott, B. P., et al. (LIGO Scientific Collaboration and Virgo Collaboration). (2016). Observation of Gravitational Waves from a Binary Black Hole Merger. *Physical Review Letters*, *116*(6), 061102.
# *   Event Horizon Telescope Collaboration, et al. (2019). First M87 Event Horizon Telescope Results. I. The Shadow of the Supermassive Black Hole. *The Astrophysical Journal Letters*, *875*(1), L1.
#
# ---

# %%
# 2nd prompt
template2 = PromptTemplate(
    template="Write a 5 line summary on the following text./n {text}",
    input_variables=["text"],
)
prompt2 = template2.invoke({"text": result.content})
print(f"Prompt2:{prompt2}")
result1 = model.invoke(prompt2)

print(f"Summary:{result1.content}")
# Out:
# Prompt2:text='Write a 5 line summary on the following text./n ## Black Hole: A Cosmic Enigma\n\n**Report Date:** October 26, 2023\n\n**Prepared By:** [Your Name/AI Assistant]\n\n**Subject:** A Comprehensive Overview of Black Holes\n\n---\n\n**1. Introduction**\n\nBlack holes are among the most fascinating and enigmatic objects in the universe. These regions of spacetime possess such intense gravitational pull that nothing, not even light, can escape their grasp. Their existence, once a purely theoretical prediction of Einstein\'s theory of general relativity, has been confirmed through decades of observational evidence. This report aims to provide a detailed exploration of black holes, covering their formation, properties, types, detection methods, and their profound implications for our understanding of gravity and the cosmos.\n\n---\n\n**2. Theoretical Foundation: General Relativity**\n\nThe concept of black holes is deeply rooted in Albert Einstein\'s **theory of general relativity**, published in 1915. General relativity describes gravity not as a force, but as a curvature of spacetime caused by the presence of mass and energy.\n\n*   **Spacetime Curvature:** Massive objects warp the fabric of spacetime around them. This curvature dictates how other objects, including light, move.\n*   **Escape Velocity:** Every celestial object has an "escape velocity" – the minimum speed required to break free from its gravitational pull. For Earth, it\'s about 11.2 km/s.\n*   **Schwarzschild Radius:** In 1916, Karl Schwarzschild derived a solution to Einstein\'s field equations that described the spacetime around a non-rotating, spherically symmetric mass. This solution revealed that if enough mass is compressed into a small enough volume, the escape velocity at its surface would exceed the speed of light. The radius at which this occurs is known as the **Schwarzschild radius ($R_s$)**.\n\n    $R_s = \\frac{2GM}{c^2}$\n\n    Where:\n    *   $G$ is the gravitational constant\n    *   $M$ is the mass of the object\n    *   $c$ is the speed of light\n\n    For a black hole, the Schwarzschild radius defines the boundary beyond which escape is impossible.\n\n---\n\n**3. Formation of Black Holes**\n\nBlack holes are believed to form through the gravitational collapse of massive objects. The primary mechanisms for their formation are:\n\n*   **Stellar-Mass Black Holes:** These are the most common type and are formed from the remnants of massive stars.\n    *   **Stellar Evolution:** Stars spend most of their lives fusing lighter elements into heavier ones in their core, generating outward pressure that counteracts the inward pull of gravity.\n    *   **Supernova Explosion:** When a massive star (typically more than 8-10 times the mass of our Sun) exhausts its nuclear fuel, the outward pressure ceases. Gravity then overwhelms the star\'s core, causing it to collapse catastrophically.\n    *   **Core Collapse:** If the core\'s mass after the collapse exceeds a certain limit (the Tolman-Oppenheimer-Volkoff limit, around 1.4-3 solar masses, depending on the equation of state of neutron-degenerate matter), it will continue to collapse indefinitely, forming a stellar-mass black hole. The outer layers of the star are expelled in a spectacular **supernova explosion**.\n\n*   **Supermassive Black Holes:** These behemoths, with masses ranging from millions to billions of solar masses, reside at the centers of most galaxies, including our own Milky Way (Sagittarius A*). Their formation is less well understood but likely involves:\n    *   **Mergers of Smaller Black Holes:** Stellar-mass black holes or intermediate-mass black holes may merge over cosmic time.\n    *   **Accretion of Gas and Dust:** Large amounts of gas and dust in the early universe may have rapidly fallen into central regions, leading to the formation of seed black holes that grew by accreting more matter.\n    *   **Direct Collapse of Gas Clouds:** In the early universe, massive gas clo ...
# Summary:Black holes are regions of spacetime with immense gravity, predicted by Einstein's general relativity.
# They form from the collapse of massive stars and are characterized by mass, spin, and charge.
# Detected through their gravitational effects on surrounding matter and emitted radiation, their existence is confirmed by phenomena like accretion disks and gravitational waves.
# Supermassive black holes reside at galactic centers, influencing galaxy evolution, while stellar-mass black holes originate from dying stars.
# These cosmic enigmas challenge our understanding of physics and are crucial for testing theories of gravity and quantum mechanics.
