# %%
d1=[{
    "question":"Hello",
    "answer":"Hi"
},
{
    "question":"Hello",
    "answer":"Hi"
},
]

if "question" in d1:
    print(True)
# Out:
# True

# %%
if "Hi" not in d1:
    print(True)
# Out:
# True
