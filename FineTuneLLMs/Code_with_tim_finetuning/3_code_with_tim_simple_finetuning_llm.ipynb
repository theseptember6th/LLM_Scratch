# %%
import json
with open("/content/drive/MyDrive/finetuning/learn_withcode_with_tim_finetuning/json_extraction_dataset_500.json","r") as f:
  file=json.load(f)
print(file)
# Out:
# [{'input': "Extract the product information:\n<div class='product'><h2>Asus ROG Strix</h2><span class='price'>$1106</span><span class='category'>electronics</span><span class='brand'>Amazon</span></div>", 'output': {'name': 'Asus ROG Strix', 'price': '$1106', 'category': 'electronics', 'manufacturer': 'Amazon'}}, {'input': "Extract the product information:\n<div class='product'><h2>iPad Air</h2><span class='price'>$1344</span><span class='category'>audio</span><span class='brand'>Dell</span></div>", 'output': {'name': 'iPad Air', 'price': '$1344', 'category': 'audio', 'manufacturer': 'Dell'}}, {'input': "Extract the product information:\n<div class='product'><h2>Google Pixel 7</h2><span class='price'>$712</span><span class='category'>smartphones</span><span class='brand'>Dell</span></div>", 'output': {'name': 'Google Pixel 7', 'price': '$712', 'category': 'smartphones', 'manufacturer': 'Dell'}}, {'input': "Extract the product information:\n<div class='product'><h2>Bose QuietComfort 4
# ...

# %%
file[1]
# Out:
# {'input': "Extract the product information:\n<div class='product'><h2>iPad Air</h2><span class='price'>$1344</span><span class='category'>audio</span><span class='brand'>Dell</span></div>",
#  'output': {'name': 'iPad Air',
#   'price': '$1344',
#   'category': 'audio',
#   'manufacturer': 'Dell'}}

# %%
# !pip uninstall -y unsloth peft

# !pip install unsloth trl peft accelerate bitsandbytes
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.7/53.7 kB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 MB 14.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 423.1/423.1 kB 41.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 13.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 506.8/506.8 kB 30.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 99.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 401.6/401.6 kB 31.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 87.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 74.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.4/183.4 kB 14.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.6/47.6 MB 12.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 98.0 MB/s eta 0:00:00
# ...

# %%
# for GPU check
import torch

# Step 1: Check if GPU is available
gpu_available = torch.cuda.is_available()
print("CUDA available:", gpu_available)

# Step 2: If GPU is available, get its name
if gpu_available:
    gpu_name = torch.cuda.get_device_name(0)
else:
    gpu_name = None

print("GPU:", gpu_name)
# Out:
# CUDA available: True
# GPU: Tesla T4

# %% [markdown]
# Below code is  from unsloth documentation,and model_name also from unsloth website,which refers huggingface site

# %%
from unsloth import FastLanguageModel
import torch

model_name="unsloth/Phi-3-mini-4k-instruct-bnb-4bit"
max_seq_length=2048 #choose sequence length
dtype=None #Auto detection

# load the model and tokenizer
model,tokenizer=FastLanguageModel.from_pretrained(
    model_name=model_name,
    max_seq_length=max_seq_length,
    dtype=dtype,
    load_in_4bit=True
)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# ==((====))==  Unsloth 2026.3.8: Fast Mistral patching. Transformers: 5.3.0.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.563 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.10.0+cu128. CUDA: 7.5. CUDA Toolkit: 12.8. Triton: 3.6.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.35. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors:   0%|          | 0.00/2.26G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/291 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/194 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# ...

# %% [markdown]
# Sample of my dataset

# %%
"""[
  {
    "input": "Extract the product information:\n<div class='product'><h2>Asus ROG Strix</h2><span class='price'>$1106</span><span class='category'>electronics</span><span class='brand'>Amazon</span></div>",
    "output": {
      "name": "Asus ROG Strix",
      "price": "$1106",
      "category": "electronics",
      "manufacturer": "Amazon"
    }
  },
  {
    "input": "Extract the product information:\n<div class='product'><h2>iPad Air</h2><span class='price'>$1344</span><span class='category'>audio</span><span class='brand'>Dell</span></div>",
    "output": {
      "name": "iPad Air",
      "price": "$1344",
      "category": "audio",
      "manufacturer": "Dell"
    }
  },
]
"""

# %% [markdown]
# ["input"] is a string while ["output"] is a dictionary/json,so we need to parse ["output"] to string

# %%
from datasets import Dataset
import json

#Step 1: define a function to format each example
def format_prompt(example):
  output_str=json.dumps(example["output"])
  formatted=f"### Input:{example["input"]}\n ###Output: {output_str} <|endoftext|>"
  return formatted

#step 2: Now using that function to format all items in your file
formatted_data=[]
for item in file:
  formatted_data.append(format_prompt(item))

#step 3:Create a Hugging Face Dataset
dataset=Dataset.from_dict({"text":formatted_data})

#step 4: check the first example
print(dataset[0])
# Out:
# {'text': '### Input:Extract the product information:\n<div class=\'product\'><h2>Asus ROG Strix</h2><span class=\'price\'>$1106</span><span class=\'category\'>electronics</span><span class=\'brand\'>Amazon</span></div>\n ###Output: {"name": "Asus ROG Strix", "price": "$1106", "category": "electronics", "manufacturer": "Amazon"} <|endoftext|>'}

# %%
print(dataset)
# Out:
# Dataset({
#     features: ['text'],
#     num_rows: 500
# })

# %%
# Add LoRA adapters
model=FastLanguageModel.get_peft_model(
    model,
    r=64,#LoRA rank - higher =more capacity,more memory
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj",
                  "gate_proj", "up_proj", "down_proj",],
    lora_alpha=128,#LoRA scaling factor (usually 2x rank)
    lora_dropout=0,#Supports any,but =0 is optimized
    bias="none",
    use_gradient_checkpointing="unsloth",#unsloth's optimized version
    random_state=3407,
    use_rslora=False,#Rank stabilized LoRA
    loftq_config=None,#LoftQ
)
# Out:
# Unsloth 2026.3.8 patched 32 layers with 32 QKV layers, 32 O layers and 32 MLP layers.

# %%
from trl import SFTTrainer
from transformers import TrainingArguments

# Training arguments optimized for Unsloth
trainer = SFTTrainer(
    model=model,
    tokenizer=tokenizer,
    train_dataset=dataset,
    dataset_text_field="text",
    max_seq_length=max_seq_length,
    dataset_num_proc=2,
    args=TrainingArguments(
        per_device_train_batch_size=2,
        gradient_accumulation_steps=4,  # Effective batch size = 8
        warmup_steps=10,
        num_train_epochs=3,
        learning_rate=2e-4,
        fp16=not torch.cuda.is_bf16_supported(),
        bf16=torch.cuda.is_bf16_supported(),
        logging_steps=25,
        optim="adamw_8bit",
        weight_decay=0.01,
        lr_scheduler_type="linear",
        seed=3407,
        output_dir="outputs",
        save_strategy="epoch",
        save_total_limit=2,
        dataloader_pin_memory=False,
    ),
)
# Out:
# Unsloth: Tokenizing ["text"] (num_proc=6):   0%|          | 0/500 [00:00<?, ? examples/s]

# %%
# train the model
trainer_stats=trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 500 | Num Epochs = 3 | Total steps = 189
# O^O/ \_/ \    Batch size per device = 2 | Gradient accumulation steps = 4
# \        /    Data Parallel GPUs = 1 | Total batch size (2 x 4 x 1) = 8
#  "-____-"     Trainable parameters = 119,537,664 of 3,940,617,216 (3.03% trained)
#     <div>
#
#       <progress value='189' max='189' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [189/189 10:19, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>25</td>
#       <td>0.470799</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.150418</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>0.134932</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.123500</td>
# ...

# %%
import json

# Test the fine-tuned model
FastLanguageModel.for_inference(model) # Enable native 2x faster inference

# Test prompt
messages = [
    {"role": "user", "content": "Extract the product information:\n<div class='product'><h2>iPad Air</h2><span class='price'>$1344</span><span class='category'>audio</span><span class='brand'>Dell</span></div>"},
]

# `apply_chat_template` can return a BatchEncoding object (dict) if add_generation_prompt is True.
# We need to ensure we pass the actual tensors to `generate`.
encoded_input = tokenizer.apply_chat_template(
    messages,
    tokenize=True,
    add_generation_prompt=True,
    return_tensors="pt",
).to("cuda")

# Generate response
from transformers import TextStreamer
text_streamer=TextStreamer(tokenizer,skip_prompt=True)
_=model.generate(
    input_ids=encoded_input["input_ids"],
    attention_mask=encoded_input["attention_mask"],
    streamer=text_streamer,
    max_new_tokens=128,
    pad_token_id=tokenizer.eos_token_id,
    use_cache=False # Explicitly set use_cache to False to prevent RuntimeError
)
# Out:
# Both `max_new_tokens` (=128) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:71: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:281: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
# {"name":
# ...

# %%
model.save_pretrained_gguf("gguf_model",tokenizer,quantization_method="q4_k_m")
# Out:
# Unsloth: Merging model weights to 16-bit format...
# config.json:   0%|          | 0.00/724 [00:00<?, ?B/s]
# Found HuggingFace hub cache directory: /root/.cache/huggingface/hub
# ...
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# Checking cache directory for required files...
# Cache check failed: model-00001-of-00002.safetensors not found in local cache.
# Not all required files found in cache. Will proceed with downloading.
# Checking cache directory for required files...
# Cache check failed: tokenizer.model not found in local cache.
# Not all required files found in cache. Will proceed with downloading.
# Unsloth: Preparing safetensor model files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.99G [00:00<?, ?B/s]
# Unsloth: Preparing safetensor model files:  50%|█████     | 1/2 [03:01<03:01, 181.48s/it]
# model-00002-of-00002.safetensors:   0%|          | 0.00/2.65G [00:00<?, ?B/s]
# ...

# %%
import os

# To list files in the current directory
print('Files in current directory:')
print(os.listdir('.'))

# To list files in a specific directory, for example, 'gguf_model_gguf'
print('\nFiles in gguf_model_gguf directory:')
print(os.listdir('gguf_model_gguf'))
# Out:
# Files in current directory:
# ['.config', 'huggingface_tokenizers_cache', 'unsloth_compiled_cache', 'gguf_model', 'gguf_model_gguf', 'drive', 'outputs', 'sample_data']
#
# Files in gguf_model_gguf directory:
# ['Modelfile', 'phi-3-mini-4k-instruct.Q4_K_M.gguf']

# %% [markdown]
# Alternatively, you can use shell commands directly in a code cell by prefixing them with an exclamation mark `!`:

# %%
# To list files in the current directory
# !ls

# To list files in a specific directory
# !ls gguf_model_gguf
# Out:
# drive	    gguf_model_gguf		  outputs      unsloth_compiled_cache
# gguf_model  huggingface_tokenizers_cache  sample_data
# Modelfile  phi-3-mini-4k-instruct.Q4_K_M.gguf

# %%
import os
from google.colab import files
gguf_files = [f for f in os.listdir("gguf_model_gguf") if f.endswith(".gguf")]
if gguf_files:
    gguf_file = os.path.join("gguf_model_gguf", gguf_files[0])
    print(f"Downloading: {gguf_file}")
    files.download(gguf_file)
# Out:
# Downloading: gguf_model_gguf/phi-3-mini-4k-instruct.Q4_K_M.gguf

# %%
import os
from google.colab import files

modelfile_path = os.path.join("gguf_model_gguf", "Modelfile")
if os.path.exists(modelfile_path):
    print(f"Downloading: {modelfile_path}")
    files.download(modelfile_path)
else:
    print(f"Modelfile not found at {modelfile_path}")
# Out:
# Downloading: gguf_model_gguf/Modelfile

# %%
model.push_to_hub_gguf(
    "COOLEmperor/model",#COOLEmperor my hugging face username
    tokenizer,
    quantization_method=["q4_k_m"],
    token="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"
)
# Out:
# Unsloth: Converting model to GGUF format...
# Unsloth: Merging model weights to 16-bit format...
# Found HuggingFace hub cache directory: /root/.cache/huggingface/hub
# ...
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# Checking cache directory for required files...
# Cache check failed: model-00001-of-00002.safetensors not found in local cache.
# Not all required files found in cache. Will proceed with downloading.
# Checking cache directory for required files...
# Cache check failed: tokenizer.model not found in local cache.
# Not all required files found in cache. Will proceed with downloading.
# Unsloth: Preparing safetensor model files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.99G [00:00<?, ?B/s]
# Unsloth: Preparing safetensor model files:  50%|█████     | 1/2 [02:53<02:53, 173.47s/it]
# model-00002-of-00002.safetensors:   0%|          | 0.00/2.65G [00:00<?, ?B/s]
# ...
