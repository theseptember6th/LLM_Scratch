# %% [markdown]
# <h1 style="color:blue" align="center">Pandas Time Series Tutorial: DateTimeIndex</h1>

# %%
import pandas as pd
df = pd.read_csv("aapl.csv",parse_dates=["Date"], index_col="Date")
df.head(2)
# Out:
# /var/folders/48/m5h2lpdd1nlc3bhw471fn9c00000gn/T/ipykernel_7336/4275520726.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df = pd.read_csv("aapl.csv",parse_dates=["Date"], index_col="Date")
#               Open    High     Low   Close    Volume
# Date
# 2017-07-07  142.90  144.75  142.90  144.18  19201712
# 2017-07-06  143.02  143.50  142.41  142.73  24128782

# %%
df.index
# Out:
# DatetimeIndex(['2017-07-07', '2017-07-06', '2017-07-05', '2017-07-03',
#                '2017-06-30', '2017-06-29', '2017-06-28', '2017-06-27',
#                '2017-06-26', '2017-06-23',
#                ...
#                '2016-07-22', '2016-07-21', '2016-07-20', '2016-07-19',
#                '2016-07-18', '2016-07-15', '2016-07-14', '2016-07-13',
#                '2016-07-12', '2016-07-11'],
#               dtype='datetime64[ns]', name='Date', length=251, freq=None)

# %% [markdown]
# <h3 style="color:purple">What is DatetimeIndex? Benefits of it</h3>

# %% [markdown]
# <h4> (1) Partial Date Index: Select Specific Months Data</h4>

# %%
df["2017-01"]
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2017-01-31  121.15  121.39  120.62  121.35  49200993
# 2017-01-30  120.93  121.63  120.66  121.63  30377503
# 2017-01-27  122.14  122.35  121.60  121.95  20562944
# 2017-01-26  121.67  122.44  121.60  121.94  26337576
# 2017-01-25  120.42  122.10  120.28  121.88  32586673
# 2017-01-24  119.55  120.10  119.50  119.97  23211038
# 2017-01-23  120.00  120.81  119.77  120.08  22050218
# 2017-01-20  120.45  120.45  119.73  120.00  32597892
# 2017-01-19  119.40  120.09  119.37  119.78  25597291
# 2017-01-18  120.00  120.50  119.71  119.99  23712961
# 2017-01-17  118.34  120.24  118.22  120.00  34439843
# 2017-01-13  119.11  119.62  118.81  119.04  26111948
# 2017-01-12  118.90  119.30  118.21  119.25  27086220
# 2017-01-11  118.74  119.93  118.60  119.75  27588593
# 2017-01-10  118.77  119.38  118.30  119.11  24462051
# 2017-01-09  117.95  119.43  117.94  118.99  33561948
# 2017-01-06  116.78  118.16  116.47  117.91  31751900
# 2017-01-05  115.92  116.86  115.81  116.61  22193587
# 2017-01-04  115.85  116.51  115.75  116.02  21118116
# 2017-01-03  115.80  116.33  114.76  116.15  28781865

# %%
print(f"Start date: {df.index.min()}")
print(f"End date: {df.index.max()}")
# Out:
# Start date: 2016-07-11 00:00:00
# End date: 2017-07-07 00:00:00

# %%
df=df.sort_index()

# %%
df.loc["2017-01-01":"2017-01-07"]
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2017-01-03  115.80  116.33  114.76  116.15  28781865
# 2017-01-04  115.85  116.51  115.75  116.02  21118116
# 2017-01-05  115.92  116.86  115.81  116.61  22193587
# 2017-01-06  116.78  118.16  116.47  117.91  31751900

# %%
df.iloc[0]
# Out:
# Open            96.75
# High            97.65
# Low             96.73
# Close           96.98
# Volume    23794945.00
# Name: 2016-07-11 00:00:00, dtype: float64

# %%
df.loc['2017-06'].head()
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2017-06-01  153.17  153.33  152.22  153.18  16404088
# 2017-06-02  153.58  155.45  152.89  155.45  27770715
# 2017-06-05  154.34  154.45  153.46  153.93  25331662
# 2017-06-06  153.90  155.81  153.78  154.45  26624926
# 2017-06-07  155.02  155.98  154.48  155.37  21069647

# %%
df.loc["2017-01"]["Close"].mean()
# Out:
# np.float64(119.57000000000001)

# %%
df["Close"].resample("M").mean()
# Out:
# /var/folders/48/m5h2lpdd1nlc3bhw471fn9c00000gn/T/ipykernel_7336/167506527.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df["Close"].resample("M").mean()
# Date
# 2016-07-31     99.473333
# 2016-08-31    107.665217
# 2016-09-30    110.857143
# 2016-10-31    115.707143
# 2016-11-30    110.154286
# 2016-12-31    114.335714
# 2017-01-31    119.570000
# 2017-02-28    133.713684
# 2017-03-31    140.617826
# 2017-04-30    142.886842
# 2017-05-31    152.227727
# 2017-06-30    147.831364
# 2017-07-31    143.625000
# Freq: ME, Name: Close, dtype: float64

# %%
df["Close"].resample("M").mean().plot()
# Out:
# /var/folders/48/m5h2lpdd1nlc3bhw471fn9c00000gn/T/ipykernel_7336/1019534481.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df["Close"].resample("M").mean().plot()
# <Axes: xlabel='Date'>

# %%
df["Close"].resample("W").mean().plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df["Close"].resample("Q").mean().plot()
# Out:
# /var/folders/48/m5h2lpdd1nlc3bhw471fn9c00000gn/T/ipykernel_7336/615487283.py:1: FutureWarning: 'Q' is deprecated and will be removed in a future version, please use 'QE' instead.
#   df["Close"].resample("Q").mean().plot()
# <Axes: xlabel='Date'>

# %%
df["Close"].resample("Q").mean().plot(kind="bar")
# Out:
# /var/folders/48/m5h2lpdd1nlc3bhw471fn9c00000gn/T/ipykernel_7336/527497186.py:1: FutureWarning: 'Q' is deprecated and will be removed in a future version, please use 'QE' instead.
#   df["Close"].resample("Q").mean().plot(kind="bar")
# <Axes: xlabel='Date'>

# %% [markdown]
# <h4>Average price of aapl's stock in June, 2017</h4>

# %%
df['2017-06'].Close.mean()
# Out:
# 147.8313636363636

# %%
df['2017'].head(2)
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2017-07-07  142.90  144.75  142.90  144.18  19201712
# 2017-07-06  143.02  143.50  142.41  142.73  24128782

# %% [markdown]
# <h4>(2) Select Date Range</h4>

# %%
df['2017-01-08':'2017-01-03']
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2017