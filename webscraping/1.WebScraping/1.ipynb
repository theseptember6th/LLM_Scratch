# %%
from bs4 import BeautifulSoup

# %%
with open("index.html","r") as f:
    doc=BeautifulSoup(f,"html.parser")

# %%
doc
# Out:
# <html>
# <head>
# <title>Your Title Here</title>
# </head>
# <body bgcolor="FFFFFF">
# <center><img align="BOTTOM" src="clouds.jpg"/></center>
# <hr/>
# <a href="http://somegreatsite.com">Link Name</a>
#
#     is a link to another nifty site
#
#     <h1>This is a Header</h1>
# <h2>This is a Medium Header</h2>
#
#     Send me mail at
#     <a href="mailto:support@yourcompany.com"> support@yourcompany.com</a>.
#
#     <p>This is a new paragraph!</p>
# <p>
# <b color="red">This is a new paragraph!</b>
# <br/>
# <b><i>This is a new sentence without a paragraph break, in bold italics.</i></b>
# </p>
# <hr/>
# </body>
# </html>

# %%
doc.prettify()
# Out:
# '<html>\n <head>\n  <title>\n   Your Title Here\n  </title>\n </head>\n <body bgcolor="FFFFFF">\n  <center>\n   <img align="BOTTOM" src="clouds.jpg"/>\n  </center>\n  <hr/>\n  <a href="http://somegreatsite.com">\n   Link Name\n  </a>\n  is a link to another nifty site\n  <h1>\n   This is a Header\n  </h1>\n  <h2>\n   This is a Medium Header\n  </h2>\n  Send me mail at\n  <a href="mailto:support@yourcompany.com">\n   support@yourcompany.com\n  </a>\n  .\n  <p>\n   This is a new paragraph!\n  </p>\n  <p>\n   <b color="red">\n    This is a new paragraph!\n   </b>\n   <br/>\n   <b>\n    <i>\n     This is a new sentence without a paragraph break, in bold italics.\n    </i>\n   </b>\n  </p>\n  <hr/>\n </body>\n</html>\n'

# %%
tag=doc.title
tag
# Out:
# <title>Your Title Here</title>

# %%
tag.string
# Out:
# 'Your Title Here'

# %%
tag.string="hello"
print(tag)
# Out:
# <title>hello</title>

# %%
print(doc)
# Out:
# <html>
# <head>
# <title>hello</title>
# </head>
# <body bgcolor="FFFFFF">
# <center><img align="BOTTOM" src="clouds.jpg"/></center>
# <hr/>
# <a href="http://somegreatsite.com">Link Name</a>
#
#     is a link to another nifty site
#
#     <h1>This is a Header</h1>
# <h2>This is a Medium Header</h2>
#
#     Send me mail at
#     <a href="mailto:support@yourcompany.com"> support@yourcompany.com</a>.
#
#     <p>This is a new paragraph!</p>
# <p>
# <b color="red">This is a new paragraph!</b>
# <br/>
# <b><i>This is a new sentence without a paragraph break, in bold italics.</i></b>
# </p>
# <hr/>
# </body>
# </html>

# %%
tag=doc.find("a")
tag
# Out:
# <a href="http://somegreatsite.com">Link Name</a>

# %%
tags=doc.find_all("a")
tags
# Out:
# [<a href="http://somegreatsite.com">Link Name</a>,
#  <a href="mailto:support@yourcompany.com"> support@yourcompany.com</a>]

# %%
tags=doc.find_all("p")
tags
# Out:
# [<p>This is a new paragraph!</p>,
#  <p>
#  <b color="red">This is a new paragraph!</b>
#  <br/>
#  <b><i>This is a new sentence without a paragraph break, in bold italics.</i></b>
#  </p>]

# %%
first_p=tags[0]
all_b_tags=doc.find_all("b")
print(all_b_tags)
# Out:
# [<b color="red">This is a new paragraph!</b>, <b><i>This is a new sentence without a paragraph break, in bold italics.</i></b>]

# %%
import requests
from bs4 import BeautifulSoup

# %%
url="https://www.newegg.com/msi-geforce-rtx-5070-12g-ventus-2x-oc-video-card/p/N82E16814137994?Item=N82E16814137994&cm_sp=Homepage_SS-_-P1_14-137-994-_-01302026"

# %%
results=requests.get(url)
results
# Out:
# <Response [200]>

# %%
results.text
# Out:
# '<!DOCTYPE html><!DOCTYPE html><html lang="en-us" class="show-tab-store is-new"><head><meta charSet="utf-8"/><link rel="preload" as="image" href="https://c1.neweggimages.com/WebResource/Themes/Nest/logos/Newegg_full_color_logo_RGB.SVG"/><link rel="preload" as="image" href="https://promotions.newegg.com/pcbuilder/374x50.jpg"/><link rel="preload" as="image" href="https://c1.neweggimages.com/brandimage/Brand1312.gif"/><link rel="preload" as="image" href="https://c1.neweggimages.com/productimage/nb640/14-137-994-02.jpg"/><link rel="preload" as="image" href="https://c1.neweggimages.com/productimage/nb640/14-137-994-12.jpg"/><link rel="preload" as="image" href="https://c1.neweggimages.com/productimage/nb640/14-137-994-03.jpg"/><link rel="preload" as="image" href="https://c1.neweggimages.com/productimage/nb640/14-137-994-04.jpg"/><link rel="preload" as="image" href="https://c1.neweggimages.com/productimage/nb640/14-137-994-05.jpg"/><link rel="preload" as="image" href="https://c1.neweggimages.com/productimage/nb640/14-137-994-06.jpg"/><link rel="preload" as="image" href="https://c1.neweggimages.com/productimage/nb640/14-137-994-07.jpg"/><link rel="preload" as="image" href="https://c1.neweggimages.com/productimage/nb640/14-137-994-08.jpg"/><link rel="preload" as="image" href="https://c1.neweggimages.com/productimage/nb640/14-137-994-09.jpg"/><link rel="preload" as="image" href="https://c1.neweggimages.com/productimage/nb640/14-137-994-01.jpg"/><link rel="preload" as="image" href="https://c1.neweggimages.com/productimage/nb640/14-137-994-10.jpg"/><link rel="preload" as="image" href="https://c1.neweggimages.com/productimage/nb640/14-137-994-11.jpg"/><link rel="preload" as="image" href="https://c1.neweggimages.com/ProductImageCompressAll60/14-137-994-02.jpg"/><link rel="preload" as="image" href="https://c1.neweggimages.com/ProductImageCompressAll60/14-137-994-12.jpg"/><link rel="preload" as="image" href="https://c1.neweggimages.com/ProductImageCompressAll60/14-137-994-03.jpg"/><link rel="preload" as="image" href="https://c1.neweggimages.com/ProductImageCompressAll60/14-137-994-04.jpg"/><link rel="preload" as="image" href="https://c1.neweggimages.com/ProductImageCompressAll60/14-137-994-05.jpg"/><link rel="preload" as="image" href="https://c1.neweggimages.com/ProductImageCompressAll60/14-137-994-06.jpg"/><link rel="preload" as="image" href="https://c1.neweggimages.com/ProductImageCompressAll60/14-137-994-07.jpg"/><link rel="preload" as="image" href="https://c1.neweggimages.com/ProductImageCompressAll60/14-137-994-08.jpg"/><link rel="preload" as="image" href="https://c1.neweggimages.com/ProductImageCompressAll60/14-137-994-09.jpg"/><link rel="preload" as="image" href="https://c1.neweggimages.com/ProductImageCompressAll60/14-137-994-01.jpg"/><link rel="preload" as="image" href="https://c1.neweggimages.com/ProductImageCompressAll60/14-137-994-10.jpg"/><link rel="preload" as="image" href="https://c1.neweggimages.com/ProductImageCompressAll60/14-137-994-11.jpg"/><link rel="preload" as="image" href="https://c1.neweggimages.com/WebResource/Themes/Nest/bgs/Illus_Subscription@4x.png"/><link rel="preload" as="image" href="https://c1.neweggimages.com/webresource/themes/Nest/qrcodes/qrcode-app-v3.png"/><link rel="preload" as="image" href="https://c1.neweggimages.com/WebResource/Themes/Nest/bgs/bg_our_app.png"/><title>MSI Ventus GeForce RTX 5070 Video Card RTX 5070 12G VENTUS 2X OC BLACK - Newegg.com</title><meta http-equiv="content-type" content="text/html; charset=UTF-8"/><meta name="twitter:card" content="summary_large_image"/><meta name="referrer" content="always"/><meta name="keywords" content="Newegg, Newegg.com, MSI Ventus GeForce RTX 5070 12GB GDDR7 PCI Express 5.0 ATX Video Card RTX 5070 12G VENTUS 2X OC BLACK"/><meta name="description" content="Buy MSI Ventus GeForce RTX 5070 12GB GDDR7 PCI Express 5.0 ATX Video Card RTX 5070 12G VENTUS 2X OC BLACK with fast shipping and top-rated customer service. Newegg shopping upgraded ™"/><meta property= ...

# %%
doc=BeautifulSoup(results.text,"html.parser")
doc.prettify()
# Out:
# '<!DOCTYPE html>\n<!DOCTYPE html>\n<html class="show-tab-store is-new" lang="en-us">\n <head>\n  <meta charset="utf-8"/>\n  <link as="image" href="https://c1.neweggimages.com/WebResource/Themes/Nest/logos/Newegg_full_color_logo_RGB.SVG" rel="preload"/>\n  <link as="image" href="https://promotions.newegg.com/pcbuilder/374x50.jpg" rel="preload"/>\n  <link as="image" href="https://c1.neweggimages.com/brandimage/Brand1312.gif" rel="preload"/>\n  <link as="image" href="https://c1.neweggimages.com/productimage/nb640/14-137-994-02.jpg" rel="preload"/>\n  <link as="image" href="https://c1.neweggimages.com/productimage/nb640/14-137-994-12.jpg" rel="preload"/>\n  <link as="image" href="https://c1.neweggimages.com/productimage/nb640/14-137-994-03.jpg" rel="preload"/>\n  <link as="image" href="https://c1.neweggimages.com/productimage/nb640/14-137-994-04.jpg" rel="preload"/>\n  <link as="image" href="https://c1.neweggimages.com/productimage/nb640/14-137-994-05.jpg" rel="preload"/>\n  <link as="image" href="https://c1.neweggimages.com/productimage/nb640/14-137-994-06.jpg" rel="preload"/>\n  <link as="image" href="https://c1.neweggimages.com/productimage/nb640/14-137-994-07.jpg" rel="preload"/>\n  <link as="image" href="https://c1.neweggimages.com/productimage/nb640/14-137-994-08.jpg" rel="preload"/>\n  <link as="image" href="https://c1.neweggimages.com/productimage/nb640/14-137-994-09.jpg" rel="preload"/>\n  <link as="image" href="https://c1.neweggimages.com/productimage/nb640/14-137-994-01.jpg" rel="preload"/>\n  <link as="image" href="https://c1.neweggimages.com/productimage/nb640/14-137-994-10.jpg" rel="preload"/>\n  <link as="image" href="https://c1.neweggimages.com/productimage/nb640/14-137-994-11.jpg" rel="preload"/>\n  <link as="image" href="https://c1.neweggimages.com/ProductImageCompressAll60/14-137-994-02.jpg" rel="preload"/>\n  <link as="image" href="https://c1.neweggimages.com/ProductImageCompressAll60/14-137-994-12.jpg" rel="preload"/>\n  <link as="image" href="https://c1.neweggimages.com/ProductImageCompressAll60/14-137-994-03.jpg" rel="preload"/>\n  <link as="image" href="https://c1.neweggimages.com/ProductImageCompressAll60/14-137-994-04.jpg" rel="preload"/>\n  <link as="image" href="https://c1.neweggimages.com/ProductImageCompressAll60/14-137-994-05.jpg" rel="preload"/>\n  <link as="image" href="https://c1.neweggimages.com/ProductImageCompressAll60/14-137-994-06.jpg" rel="preload"/>\n  <link as="image" href="https://c1.neweggimages.com/ProductImageCompressAll60/14-137-994-07.jpg" rel="preload"/>\n  <link as="image" href="https://c1.neweggimages.com/ProductImageCompressAll60/14-137-994-08.jpg" rel="preload"/>\n  <link as="image" href="https://c1.neweggimages.com/ProductImageCompressAll60/14-137-994-09.jpg" rel="preload"/>\n  <link as="image" href="https://c1.neweggimages.com/ProductImageCompressAll60/14-137-994-01.jpg" rel="preload"/>\n  <link as="image" href="https://c1.neweggimages.com/ProductImageCompressAll60/14-137-994-10.jpg" rel="preload"/>\n  <link as="image" href="https://c1.neweggimages.com/ProductImageCompressAll60/14-137-994-11.jpg" rel="preload"/>\n  <link as="image" href="https://c1.neweggimages.com/WebResource/Themes/Nest/bgs/Illus_Subscription@4x.png" rel="preload"/>\n  <link as="image" href="https://c1.neweggimages.com/webresource/themes/Nest/qrcodes/qrcode-app-v3.png" rel="preload"/>\n  <link as="image" href="https://c1.neweggimages.com/WebResource/Themes/Nest/bgs/bg_our_app.png" rel="preload"/>\n  <title>\n   MSI Ventus GeForce RTX 5070 Video Card RTX 5070 12G VENTUS 2X OC BLACK - Newegg.com\n  </title>\n  <meta content="text/html; charset=utf-8" http-equiv="content-type"/>\n  <meta content="summary_large_image" name="twitter:card"/>\n  <meta content="always" name="referrer"/>\n  <meta content="Newegg, Newegg.com, MSI Ventus GeForce RTX 5070 12GB GDDR7 PCI Express 5.0 ATX Video Card RTX 5070 12G VENTUS 2X OC BLACK" name="keywords"/>\n  <meta content="Buy MSI Ventus GeForce RTX 5070 12GB GDDR7 PCI Express 5 ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
prices=doc.find_all(text="$")
print(prices)
# Out:
# ['$']
# /var/folders/48/m5h2lpdd1nlc3bhw471fn9c00000gn/T/ipykernel_35933/3770817947.py:1: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   prices=doc.find_all(text="$")

# %%
parent=prices[0].parent
print(parent)
# Out:
# <div class="price-current"><span class="price-current-label"></span>$<strong>629</strong><sup>.99</sup></div>

# %%
parent.prettify()
# Out:
# '<div class="price-current">\n <span class="price-current-label">\n </span>\n $\n <strong>\n  629\n </strong>\n <sup>\n  .99\n </sup>\n</div>\n'

# %%
strong=parent.find("strong")
print(strong)
# Out:
# <strong>629</strong>

# %%
print(strong.text)
# Out:
# 629
