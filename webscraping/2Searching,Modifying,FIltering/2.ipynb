# %%
from bs4 import BeautifulSoup

# %%
with open("./index.html","r") as f:
    doc=BeautifulSoup(f,"html.parser")

# %%
doc
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <title>Educational registration form</title>
# <link crossorigin="anonymous" href="https://use.fontawesome.com/releases/v5.4.1/css/all.css" integrity="sha384-5sAR7xN1Nv6T6+dT2mhtzEpVJvfS3NScPQTrOxhwjIuvcA67KV2R5Jz6kr4abQsz" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/css?family=Roboto:300,400,500,700" rel="stylesheet"/>
# <style>
#       html,
#       body {
#         min-height: 100%;
#       }
#       body,
#       div,
#       form,
#       input,
#       select,
#       p {
#         padding: 0;
#         margin: 0;
#         outline: none;
#         font-family: Roboto, Arial, sans-serif;
#         font-size: 16px;
#         color: #eee;
#       }
#       body {
#         background: url("/uploads/media/default/0001/01/b5edc1bad4dc8c20291c8394527cb2c5b43ee13c.jpeg")
#           no-repeat center;
#         background-size: cover;
#       }
#       h1,
#       h2 {
#         text-transform: uppercase;
# ...

# %%
result=doc.find("option")
result
# Out:
# <option selected="" value="course-type">Course type*</option>

# %%
result["value"]="I changed the value"
result
# Out:
# <option selected="" value="I changed the value">Course type*</option>

# %%
result["selected"]=True

# %%
result
# Out:
# <option selected="True" value="I changed the value">Course type*</option>

# %%
result.attrs
# Out:
# {'value': 'I changed the value', 'selected': True}

# %%
tags=doc.find_all(["p","div","li"])
tags
# Out:
# [<div class="main-block">
#  <div class="left-part">
#  <i class="fas fa-graduation-cap"></i>
#  <h1>Register to our courses</h1>
#  <p>
#            W3docs provides free learning materials for programming languages like
#            HTML, CSS, Java Script, PHP etc.
#          </p>
#  <div class="btn-group">
#  <a class="btn-item" href="https://www.w3docs.com/learn-html.html">Learn HTML</a>
#  <a class="btn-item" href="https://www.w3docs.com/quiz/#">Select Quiz</a>
#  </div>
#          $2345
#        </div>
#  <form action="/">
#  <div class="title">
#  <i class="fas fa-pencil-alt"></i>
#  <h2>Register here</h2>
#  </div>
#          $123
#          <div class="info">
#  <input class="fname" name="name" placeholder="Full name" type="text"/>
#  <input name="name" placeholder="Email" type="text"/>
#  <input name="name" placeholder="Phone number" type="text"/>
#  <input name="name" placeholder="Password" type="password"/>
#  <select>
# ...

# %%
option_tag=doc.find_all(["option"],string="Undergraduate")
option_tag
# Out:
# [<option value="undergraduate">Undergraduate</option>]

# %%
tags=doc.find_all(class_="checkbox")
tags
# Out:
# [<div class="checkbox">
#  <input name="checkbox" type="checkbox"/><span>I agree to the
#              <a href="https://www.w3docs.com/privacy-policy">Privacy Poalicy for W3Docs.</a></span>
#  </div>]

# %%
import re

tags=doc.find_all(text=re.compile(r"\$.*"))
tags
# Out:
# /var/folders/48/m5h2lpdd1nlc3bhw471fn9c00000gn/T/ipykernel_51064/2174269960.py:3: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   tags=doc.find_all(text=re.compile(r"\$.*"))
# ['\n        $2345\n      ', '\n        $123\n        ']

# %%
for tag in tags:
    print(tag.strip())
# Out:
# $2345
# $123

# %%
import re

tags=doc.find_all(text=re.compile(r"\$.*"),limit=1)
tags
# Out:
# /var/folders/48/m5h2lpdd1nlc3bhw471fn9c00000gn/T/ipykernel_51064/1031436934.py:3: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   tags=doc.find_all(text=re.compile(r"\$.*"),limit=1)
# ['\n        $2345\n      ']

# %%
tags=doc.find_all("input",type="text")
tags
# Out:
# [<input class="fname" name="name" placeholder="Full name" type="text"/>,
#  <input name="name" placeholder="Email" type="text"/>,
#  <input name="name" placeholder="Phone number" type="text"/>]

# %%
for tag in tags:
    tag["placeholder"]="I changed you!"

print(tags)
# Out:
# [<input class="fname" name="name" placeholder="I changed you!" type="text"/>, <input name="name" placeholder="I changed you!" type="text"/>, <input name="name" placeholder="I changed you!" type="text"/>]

# %%
with open("Modified_html.html","w") as f:
    f.write(str(doc))
